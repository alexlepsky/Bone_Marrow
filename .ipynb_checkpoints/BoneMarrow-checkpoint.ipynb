# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import DBSCAN
from scipy.spatial import distance
import numpy as np
from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.metrics import davies_bouldin_score


F = open('13_180_HE_1.txt')
df=[]
for line in F:
    if line!='\n':
        try:
            line = line.replace(',','.')
            Y = float(line.split('\t')[0])
            X = float(line.split('\t')[1].replace('\n',''))
            df.append([X,Y])
        except:
            print(line)

df=np.array(df)
plt.figure(figsize=(80,20))
plt.axis('equal')
plt.plot(df[:,0],df[:,1],'ko',markersize=15)
plt.show()
# Out:
# X	Y

# %%
clustering = DBSCAN(eps=100, min_samples=3).fit_predict(df)

# %%
plt.figure(figsize=(80,20))
plt.axis('equal')
for i in np.unique(clustering):
    plt.plot(df[clustering[:] == i,0], df[clustering[:] == i,1], 'o', markersize=15)
plt.plot(df[clustering[:] == -1,0], df[clustering[:] == -1,1], 'ko', markersize=15)
plt.show()

# %%
print('число точек',len(clustering))
print('число кластеров',len(np.unique(clustering))-1)
df2 = pd.DataFrame([df[:,0],df[:,1],clustering])
df2=df2.T
df2=df2.drop(df2[df2[2] == -1].index)
print('среднее число кластеров',df2.groupby(2).size().mean())
print('площадь препарата',(df[:,0].max()-df[:,0].min())*(df[:,1].max()-df[:,1].min()))
# Out:
# число точек 848
# число кластеров 112
# среднее число кластеров 5.553571428571429
# площадь препарата 54044447.636767395

# %%
silhouette=[]
x=[]
for i in range(50,1500,5):
    clustering = DBSCAN(eps=i, min_samples=3).fit_predict(df)
    if (len(np.unique(clustering))!=1):
        x.append(i)
        silhouette.append(metrics.silhouette_score(df, clustering, metric='euclidean'))

# %%
plt.figure(figsize=(10,10))
plt.plot(x,silhouette)
plt.show()

# %%
import os
files = os.listdir(path="./txt")
number_of_points=[]
number_of_clusters=[]
average_in_cluster=[]
squares=[]
for currentFile in files:
    F = open('txt/' + currentFile)
    df=[]
    for line in F:
        if line!='\n':
            try:
                line = line.replace(',','.')
                Y = float(line.split('\t')[0])
                X = float(line.split('\t')[1].replace('\n',''))
                df.append([X,Y])
            except:
                continue
                #print('not number:',line)
    df=np.array(df)
    clustering = DBSCAN(eps=100, min_samples=3).fit_predict(df)
    print(currentFile)
    print('число точек',len(clustering))
    print('число кластеров',len(np.unique(clustering))-1)
    df2 = pd.DataFrame([df[:,0],df[:,1],clustering])
    df2=df2.T
    df2=df2.drop(df2[df2[2] == -1].index)
    print('среднее число кластеров',df2.groupby(2).size().mean())
    print('площадь препарата',(df[:,0].max()-df[:,0].min())*(df[:,1].max()-df[:,1].min()))
    print('')
    number_of_points.append(len(clustering))
    number_of_clusters.append(len(np.unique(clustering))-1)
    average_in_cluster.append(df2.groupby(2).size().mean())
    squares.append((df[:,0].max()-df[:,0].min())*(df[:,1].max()-df[:,1].min()))
    plt.figure(figsize=(80,80))
    plt.axis('equal')
    for i in np.unique(clustering):
        plt.plot(df[clustering[:] == i,0], df[clustering[:] == i,1], 'o', markersize=15)
    plt.plot(df[clustering[:] == -1,0], df[clustering[:] == -1,1], 'ko', markersize=15)
    plt.title(currentFile)
    plt.savefig(currentFile+'.png')
    plt.close()
# Out:
# 12_60_AE_1.txt
# число точек 732
# число кластеров 89
# среднее число кластеров 5.202247191011236
# площадь препарата 42000551.083281375
#
# 13_111_HE_1.txt
# число точек 803
# число кластеров 95
# среднее число кластеров 5.663157894736842
# площадь препарата 24173244.690727882
#
# 13_1355_AE_1.txt
# число точек 394
# число кластеров 47
# среднее число кластеров 5.319148936170213
# площадь препарата 23350732.178101864
#
# 13_1370_HE_1.txt
# число точек 645
# число кластеров 78
# среднее число кластеров 5.705128205128205
# площадь препарата 25877769.04501764
#
# 13_1414_HE_1.txt
# число точек 479
# число кластеров 60
# среднее число кластеров 5.433333333333334
# площадь препарата 20718208.114758827
#
# 13_1433_AE_1.txt
# число точек 549
# число кластеров 60
# среднее число кластеров 5.683333333333334
# площадь препарата 31022320.04004469
#
# 13_1457_HE_1.txt
# число точек 257
# число кластеров 31
# среднее число кластеров 4.741935483870968
# площадь препарата 16018018.445957948
#
# 13_1488_HE_1.txt
# число точек 445
# число кластеров 57
# среднее число кластеров 5.140350877192983
# площадь препарата 53801280.05100771
#
# 13_1628_HE_1.txt
# число точек 1362
# число кластеров 127
# среднее число кластеров 9.086614173228346
# площадь препарата 34064867.83118529
#
# 13_1718_HE_1.txt
# число точек 348
# число кластеров 41
# среднее число кластеров 3.5853658536585367
# площадь препарата 31592284.71615043
#
# 13_1749_HE_1.txt
# число точек 736
# число кластеров 75
# среднее число кластеров 7.8
# площадь препарата 38580848.539614014
#
# 13_1823_HE_1.txt
# число точек 567
# число кластеров 70
# среднее число кластеров 4.557142857142857
# площадь препарата 26724286.960475363
#
# 13_1836_HE_1.txt
# число точек 281
# число кластеров 29
# среднее число кластеров 5.206896551724138
# площадь препарата 15050759.295266122
#
# 13_1927_HE_1.txt
# число точек 349
# число кластеров 39
# среднее число кластеров 4.205128205128205
# площадь препарата 42158789.12627569
#
# 13_2021_HE_1.txt
# число точек 520
# число кластеров 53
# среднее число кластеров 6.09433962264151
# площадь препарата 45347123.99717595
#
# 13_2117_HE_1.txt
# число точек 715
# число кластеров 89
# среднее число кластеров 5.146067415730337
# площадь препарата 54571048.49661663
#
# 13_213_AE_1.txt
# число точек 126
# число кластеров 11
# среднее число кластеров 5.2727272727272725
# площадь препарата 8960675.934076523
#
# 13_368_HE_1.txt
# число точек 808
# число кластеров 98
# среднее число кластеров 4.438775510204081
# площадь препарата 35967179.07761572
#
# 13_446_HE_1.txt
# число точек 162
# число кластеров 10
# среднее число кластеров 4.0
# площадь препарата 19560103.886920936
#
# 13_648_HE_1.txt
# число точек 616
# число кластеров 61
# среднее число кластеров 4.557377049180328
# площадь препарата 53568339.49520233
#
# 13_666_HE_1.txt
# число точек 432
# число кластеров 38
# среднее число кластеров 5.0
# площадь препарата 40374793.754900336
#
# 13_698_HE_1.txt
# число точек 141
# число кластеров 14
# среднее число кластеров 4.142857142857143
# площадь препарата 10978263.472996943
#
# 13_735_HE_1.txt
# число точек 437
# число кластеров 49
# среднее число кластеров 7.142857142857143
# площадь препарата 15123870.004737133
#
# 13_768_HE_1.txt
# число точек 1268
# число кластеров 117
# среднее число кластеров 8.948717948717949
# площадь препарата 40175462.6469143
#
# 13_796_HE_1.txt
# число точек 516
# число кластеров 59
# среднее число кластеров 5.271186440677966
# площадь препарата 36339455.433218405
#
# 13_811_HE_1.txt
# число точек 1846
# число кластеров 162
# среднее число кластеров 10.104938271604938
# площадь препарата 133069245.73030676
#
# 14_1558_HE_1.txt
# число точек 545
# число кластеров 59
# среднее число кластеров 7.966101694915254
# площадь препарата 15923574.362755062
#
# 14_1677_HE_1.txt
# число точек 1228
# число кластеров 131
# среднее число кластеров 6.969465648854962
# площадь препарата 82836016.71417956
#
# 14_1961_AE_2.txt
# число точек 256
# число кластеров 35
# среднее число кластеров 4.714285714285714
# площадь препарата 18984407.985277098
#
# 14_2145_AE_1.txt
# число точек 527
# число кластеров 61
# среднее число кластеров 5.147540983606557
# площадь препарата 32524677.902752582
#
# 14_2444_HE_1.txt
# число точек 499
# число кластеров 56
# среднее число кластеров 4.232142857142857
# площадь препарата 23882774.915479686
#
# 14_2598_HE_1.txt
# число точек 1424
# число кластеров 82
# среднее число кластеров 16.28048780487805
# площадь препарата 20535652.30173946
#
# 14_2618_AE_2.txt
# число точек 99
# число кластеров 6
# среднее число кластеров 13.0
# площадь препарата 2617662.6259286613
#
# 15_1254_HE_1.txt
# число точек 57
# число кластеров 8
# среднее число кластеров 3.5
# площадь препарата 28999633.39436527
#
# 15_130_HE_1.txt
# число точек 613
# число кластеров 80
# среднее число кластеров 4.35
# площадь препарата 32574074.888136975
#
# 15_133_HE_1.txt
# число точек 567
# число кластеров 61
# среднее число кластеров 6.901639344262295
# площадь препарата 13294686.444346307
#
# 15_1402_HE_1.txt
# число точек 491
# число кластеров 51
# среднее число кластеров 5.588235294117647
# площадь препарата 30580574.874664515
#
# 15_2189_AE_1.txt
# число точек 244
# число кластеров 30
# среднее число кластеров 4.066666666666666
# площадь препарата 32248471.582240455
#
# 15_2407_HE_1.txt
# число точек 843
# число кластеров 71
# среднее число кластеров 9.830985915492958
# площадь препарата 28969251.45707839
#
# 15_2801_HE_1.txt
# число точек 286
# число кластеров 35
# среднее число кластеров 6.0285714285714285
# площадь препарата 17248764.276934184
#
# 15_2822_HE_1.txt
# число точек 338
# число кластеров 33
# среднее число кластеров 4.757575757575758
# площадь препарата 59083939.29857371
#
# 15_808_HE_1.txt
# число точек 420
# число кластеров 45
# среднее число кластеров 5.644444444444445
# площадь препарата 177137394.49833858
#
# 16_1124_HE_1.txt
# число точек 1006
# число кластеров 117
# среднее число кластеров 7.2905982905982905
# площадь препарата 66009760.9289927
#
# 16_2104_AE_1.txt
# число точек 1246
# число кластеров 126
# среднее число кластеров 8.380952380952381
# площадь препарата 31928203.01582632
#
# 16_608_AE_1.txt
# число точек 54
# число кластеров 5
# среднее число кластеров 5.4
# площадь препарата 4756534.066061734
#
# 16_70_AE_1.txt
# число точек 188
# число кластеров 22
# среднее число кластеров 4.7727272727272725
# площадь препарата 61136699.03135508
#
# 17_1588_AE.txt
# число точек 529
# число кластеров 60
# среднее число кластеров 6.583333333333333
# площадь препарата 26459399.89492792
#
# 17_1604_AE_1.txt
# число точек 186
# число кластеров 23
# среднее число кластеров 4.913043478260869
# площадь препарата 11679072.445371542
#
# 17_1807_AE_1.txt
# число точек 562
# число кластеров 60
# среднее число кластеров 6.916666666666667
# площадь препарата 16260596.650442887
#
# 17_1887.txt
# число точек 2809
# число кластеров 118
# среднее число кластеров 22.364406779661017
# площадь препарата 44781265.942029
#
# 17_801.txt
# число точек 669
# число кластеров 53
# среднее число кластеров 10.81132075471698
# площадь препарата 13838894.978201086
#
# 17_904.txt
# число точек 1304
# число кластеров 50
# среднее число кластеров 24.84
# площадь препарата 21909246.466047656

# %%
table=pd.DataFrame([number_of_points,number_of_clusters,average_in_cluster,squares],columns=files,
                   index=['всего точек','всего кластеров','среднее чилос точек в кластере','площадь препарата'])
table=table.T
writer = pd.ExcelWriter('bonemarrow.xlsx', engine='xlsxwriter')
table.to_excel(writer)
writer.save()

# %% [markdown]
# Расстояние между балками

# %%
df_balki = pd.read_csv('13_111_balki.csv',delimiter='\t')

# %%
for i in range(len(df_balki)):
    df_balki.iloc[i,0] = float(df_balki.iloc[i,0].replace(',','.'))
    df_balki.iloc[i,1] = float(df_balki.iloc[i,1].replace(',','.'))
df_balki=df_balki.reindex(columns=['y','X'])

# %%
F = open('13_111_megi.txt')
df_megi=[]
for line in F:
    if line!='\n':
        try:
            line = line.replace(',','.')
            Y = float(line.split('\t')[0])
            X = float(line.split('\t')[1].replace('\n',''))
            df_megi.append([X,Y])
        except:
            print(line)

df_megi=np.array(df_megi)
# Out:
# X	Y

# %%
b = np.array(df_balki.values[:-6])
d = []
plt.figure(figsize=(50,50))
plt.axis('equal')
for i in range(len(df_megi)):
    a = np.array([df_megi[i]])
    c = np.array([b[np.argmin(distance.cdist(b, a, 'euclidean'))]])
    plt.plot([a[0,0],c[0,0]],[a[0,1],c[0,1]],'r',linewidth = 1)
    d.append(np.min(distance.cdist(b, a, 'euclidean')))
plt.scatter(df_megi[:,0],df_megi[:,1],s=100,c='b')
plt.scatter(df_balki.iloc[:-6,0].values,df_balki.iloc[:-6,1].values,s=30,c='k')
plt.show()

# %%
np.mean(d)
# Out:
# 197.08729094968464

# %%
plt.figure(figsize=(15,5))
plt.plot(np.sort(d),'ko',markersize=1)

# %%
dis = [0 for i in range(7)]
for k in range(len(d)):
    if (d[k]>=0) and (d[k]<10):
        dis[0]+=1
if (d[k]>=0) and (d[k]<10):
        dis[0]+=1

# %%
total_d = []
import os
files = os.listdir(path="./Гистотопография (меги и балки) ПМФ JAK2/Гистотопография (меги и балки)")

for j in range(5,len(files),2):
    print(files[j])
    df_balki = pd.read_csv('./Гистотопография (меги и балки) ПМФ JAK2/Гистотопография (меги и балки)/' 
                           + files[j],delimiter='\t')
    for i in range(len(df_balki)):
        df_balki.iloc[i,0] = float(df_balki.iloc[i,0].replace(',','.'))
        df_balki.iloc[i,1] = float(df_balki.iloc[i,1].replace(',','.'))
        df_balki=df_balki.reindex(columns=['y','X'])
    print(files[j+1])
    F = open('./Гистотопография (меги и балки) ПМФ JAK2/Гистотопография (меги и балки)/'+files[int(j+1)])
    df_megi=[]
    for line in F:
        if line!='\n' and line!='# Caption':
            try:
                #line = line.replace(',','.')
                Y = float(line.split('\t')[0])
                X = float(line.split('\t')[1].replace('\n',''))
                df_megi.append([X,Y])
            except:
                print(line)
    
    df_megi=np.array(df_megi)
    b = np.array(df_balki.values[:-6])
    d = []
    plt.figure(figsize=(50,50))
    plt.axis('equal')
    for i in range(len(df_megi)):
        a = np.array([df_megi[i]])
        c = np.array([b[np.argmin(distance.cdist(b, a, 'euclidean'))]])
        #plt.plot([a[0,0],c[0,0]],[a[0,1],c[0,1]],'r',linewidth = 1)
        d.append(np.min(distance.cdist(b, a, 'euclidean')))
    #plt.scatter(df_megi[:,0],df_megi[:,1],s=100,c='b')
    #plt.scatter(df_balki.iloc[:-6,0].values,df_balki.iloc[:-6,1].values,s=30,c='k')
    #plt.show()
    total_d.append(np.mean(d))
# Out:
# 13_1714 балки.csv
# 13_1714 меги.txt
# C:\Users\Lepsky\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-20957fe920a7> in <module>
#      22     for i in range(len(df_megi)):
#      23         a = np.array([df_megi[i]])
# ---> 24         c = np.array([b[np.argmin(distance.cdist(b, a, 'euclidean'))]])
#      25         #plt.plot([a[0,0],c[0,0]],[a[0,1],c[0,1]],'r',linewidth = 1)
#      26         d.append(np.min(distance.cdist(b, a, 'euclidean')))
#
# ~\Anaconda3\lib\site-packages\scipy\spatial\distance.py in cdist(XA, XB, metric, *args, **kwargs)
#    2755         if metric_name is not None:
#    2756             XA, XB, typ, kwargs = _validate_cdist_input(XA, XB, mA, mB, n,
# -> 2757                                                         metric_name, **kwargs)
#    2758             # get cdist wrapper
#    2759             cdist_fn = getattr(_distance_wrap,
#
# ~\Anaconda3\lib\site-packages\scipy\spatial\distance.py in _validate_cdist_input(XA, XB, mA, mB, n, metric_name, **kwargs)
#     250         # validate data
#     251         XA = _convert_to_type(XA, out_type=typ)
# --> 252         XB = _convert_to_type(XB, out_type=typ)
#     253
#     254         # validate kwargs
#
# ~\Anaconda3\lib\site-packages\scipy\spatial\distance.py in _convert_to_type(X, out_type)
#     186
#     187 def _convert_to_type(X, out_type):
# --> 188     return np.ascontiguousarray(X, dtype=out_type)
#     189
#     190
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in ascontiguousarray(a, dtype)
#     630
#     631     """
# --> 632     return array(a, dtype, copy=False, order='C', ndmin=1)
#     633
#     634
#
# ValueError: could not convert string to float: '12363,700068736850880'

# %%
files[0]
# Out:
# '13_1714 балки.csv'

# %%
t = pd.read_table('./Гистотопография (меги и балки) ПМФ JAK2/Гистотопография (меги и балки)/13_1714 меги.txt'
                  ,names=[0,1]).dropna().drop(0)
# Out:
# C:\Users\Lepsky\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.

# %%
t[0].values.replace(',','.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-44771dd6b9f1> in <module>
# ----> 1 t[0].values.replace(',','.')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'replace'

# %%
t[0]
# Out:
# 1       12363,700068736850880
# 2       12417,408230622551860
# 3       12459,909600625638630
# 4       12247,435990463945930
# 5       12242,694102075171030
# 6       12532,442930424293080
# 7       11908,687648764156620
# 8       11919,752055004630160
# 9       12107,144459109147650
# 10      12159,798868019564910
# 11      11959,619042569507660
# 12      11962,604675999476970
# 13      11926,074572856328810
# 14      12031,449870384642050
# 15      12019,507336664766630
# 16      12046,553663030366810
# 17      12041,460523649831880
# 18      11989,651002365077150
# 19      12052,700555386185440
# 20      12045,148659063323070
# 21      12082,030013198233060
# 22      12065,872467577224600
# 23      12084,840021132320540
# 24      12078,868754272383740
# 25      12008,618555920174910
# 26      11939,246485047367970
# 27      12067,101846048388320
# 28      12126,956900289906120
# 29      12147,329457812047620
# 30      12214,067146246645280
#                 ...
# 1750    12690,648262358905410
# 1751    13079,625495880522070
# 1752    13064,346077738917300
# 1753    12723,138979096802360
# 1754    12737,715895254885250
# 1755    12700,658915624095240
# 1756    12564,933647162190030
# 1757    13267,862787610703890
# 1758    13299,826627860958980
# 1759    12758,966580256428640
# 1760    12547,195472078257810
# 1761    13181,103792645724750
# 1762    13263,296524717809010
# 1763    13410,646315761568980
# 1764    12813,761734971150870
# 1765    13344,786754806371390
# 1766    13364,281184849111010
# 1767    13367,442443774960340
# 1768    13525,647775709570850
# 1769    13560,070372902153400
# 1770    13107,023073237884090
# 1771    12653,942533719875430
# 1772    12706,630182484032050
# 1773    12715,762708269820000
# 1774    12724,017106576204240
# 1775    12806,034213152408480
# 1776    12742,282158147778320
# 1777    12737,891520750765270
# 1778    12784,432277159103250
# 1779    14506,558836283211350
# Name: 0, Length: 1779, dtype: object
